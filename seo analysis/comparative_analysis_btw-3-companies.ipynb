# %% [markdown]
# # Problem Statement:

# %% [markdown]
# A comparative analysis between competitors that related to mindadda.
#
# <b>Assumption</b>:
# 1. <i>BYJUS </i>- a well developed one.
# 2. <i>MIDBRAIN ACADEMY</i> - a moderate one.
# 3. <i>MINDADDA</i> - Starting company.

# %% [markdown]
# # Data collection Process

# %% [markdown]
# <p style="text-align:center">Used a tool named '<b>Screaming frog SEO Spider</b>' to collect the data from each web page from the source main link that user provided at input box which highlighted in below image</p><br/><hr/>

# %% [markdown]
# <img src="first.png"/>

# %% [markdown]
# <h6>After clicking on start, the crawling process will begin</h6>

# %% [markdown]
# From below image there are two points:
# 1. limitation of 500 urls scraping
# 2. Second thing is we can export in to csv file - which is the input for our analysis

# %% [markdown]
# <img src='second.png'/>

# %% [markdown]
# ### For limitation of URLS extraction:
# <p> we developed our own python library to extract all urls contains in their website.</p>
# <img src='third.png'/>

# %% [markdown]
# # Data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#BYJUS Dataset loading
df1 = pd.read_csv('byjus_data.csv')
df1.head(5)
# Out:
#                                              Address  \
# 0                                 https://byjus.com/
# 1    https://byjus.com/commerce/ts-grewal-solutions/
# 2  https://byjus.com/ncert-solutions-class-9-scie...
# 3                     https://byjus.com/ncert-books/
# 4              https://byjus.com/pseb/pseb-syllabus/
#
#                     Content  Status Code Status Indexability  \
# 0  text/html; charset=UTF-8          200     OK    Indexable
# 1  text/html; charset=UTF-8          200     OK    Indexable
# 2  text/html; charset=UTF-8          200     OK    Indexable
# 3  text/html; charset=UTF-8          200     OK    Indexable
# 4  text/html; charset=UTF-8          200     OK    Indexable
#
#   Indexability Status                                            Title 1  \
# 0                 NaN  e Learning for Online Courses like UPSC, K3, K...
# 1                 NaN  TS Grewal Solutions - Class 11th and 12th 20 Exam
# 2                 NaN  NCERT Solutions Class 11 Chemistry Chapter 4 S...
# 3                 NaN  NCERT Book PDF Download For Free (2020-21) - C...
# 4                 NaN  Punjab School Education Board Syllabus - Get t...
#
#    Title 1 Length  Title 1 Pixel Width  \
# 0              83                  805
# 1              49                  457
# 2              83                  784
# 3              63                  626
# 4              74                  694
#
#                                   Meta Description 1  ...  \
# 0  Online Courses for UPSC, K3, K10, K12, CBSE NC...  ...
# 1  Find out TS Grewal Solutions for CBSE class 11...  ...
# 2  Get NCERT Solutions Class 11 Chemistry Chapter...  ...
# 3  Download latest (2020-21) NCERT Books in Engli...  ...
# 4  Punjab School Education Board syllabus is prep...  ...
#
#    Closest Similarity Match  No. Near Duplicates  Spelling Errors  \
# 0                       NaN                  NaN              NaN
# 1                       NaN                  NaN              NaN
# 2                       NaN                  NaN              NaN
# 3                       NaN                  NaN              NaN
# 4                       NaN                  NaN              NaN
#
#    Grammar Errors                              Hash  Response Time  \
# 0             NaN  18e59a66ea7ac61b6a9a354bb996084f          0.233
# 1             NaN  478a4e91761196b47815e9408d66255f          0.475
# 2             NaN  865063ea93bd47c82662777ba17cf05e          0.400
# 3             NaN  996e51b790d5203fba5244a3e277c5a6          0.492
# 4             NaN  c34fb153fcae80c637a41f1d1fddb5ec          0.365
#
#   Last Modified  Redirect URL Redirect Type  \
# 0           NaN           NaN           NaN
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN
#
#                                  URL Encoded Address
# 0                                 https://byjus.com/
# 1    https://byjus.com/commerce/ts-grewal-solutions/
# 2  https://byjus.com/ncert-solutions-class-9-scie...
# 3                     https://byjus.com/ncert-books/
# 4              https://byjus.com/pseb/pseb-syllabus/
#
# [5 rows x 50 columns]

# %%
df1.shape
# Out:
# (481, 50)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Address                         481 non-null    object
#  1   Content                         481 non-null    object
#  2   Status Code                     481 non-null    int64
#  3   Status                          481 non-null    object
#  4   Indexability                    481 non-null    object
#  5   Indexability Status             8 non-null      object
#  6   Title 1                         473 non-null    object
#  7   Title 1 Length                  481 non-null    int64
#  8   Title 1 Pixel Width             481 non-null    int64
#  9   Meta Description 1              471 non-null    object
#  10  Meta Description 1 Length       481 non-null    int64
#  11  Meta Description 1 Pixel Width  481 non-null    int64
#  12  Meta Keyword 1                  0 non-null      float64
#  13  Meta Keywords 1 Length          481 non-null    int64
#  14  H1-1                            460 non-null    object
#  15  H1-1 length                     481 non-null    int64
#  16  H2-1                            380 non-null    object
#  17  H2-1 length                     481 non-null    int64
#  18  H2-2                            285 non-null    object
#  19  H2-2 length                     481 non-null    int64
#  20  Meta Robots 1                   471 non-null    object
#  21  X-Robots-Tag 1                  0 non-null      float64
#  22  Meta Refresh 1                  0 non-null      float64
#  23  Canonical Link Element 1        473 non-null    object
#  24  rel="next" 1                    0 non-null      float64
#  25  rel="prev" 1                    0 non-null      float64
#  26  HTTP rel="next" 1               0 non-null      float64
#  27  HTTP rel="prev" 1               0 non-null      float64
#  28  Size (bytes)                    481 non-null    int64
#  29  Word Count                      481 non-null    int64
#  30  Text Ratio                      481 non-null    float64
#  31  Crawl Depth                     481 non-null    int64
#  32  Link Score                      0 non-null      float64
#  33  Inlinks                         481 non-null    int64
#  34  Unique Inlinks                  481 non-null    int64
#  35  % of Total                      481 non-null    float64
#  36  Outlinks                        481 non-null    int64
#  37  Unique Outlinks                 481 non-null    int64
#  38  External Outlinks               481 non-null    int64
#  39  Unique External Outlinks        481 non-null    int64
#  40  Closest Similarity Match        0 non-null      float64
#  41  No. Near Duplicates             0 non-null      float64
#  42  Spelling Errors                 0 non-null      float64
#  43  Grammar Errors                  0 non-null      float64
#  44  Hash                            473 non-null    object
#  45  Response Time                   481 non-null    float64
#  46  Last Modified                   0 non-null      float64
#  47  Redirect URL                    8 non-null      object
#  48  Redirect Type                   8 non-null      object
#  49  URL Encoded Address             481 non-null    object
# dtypes: float64(16), int64(18), object(16)
# memory usage: 188.0+ KB

# %%
df1.columns
# Out:
# Index(['Address', 'Content', 'Status Code', 'Status', 'Indexability',
#        'Indexability Status', 'Title 1', 'Title 1 Length',
#        'Title 1 Pixel Width', 'Meta Description 1',
#        'Meta Description 1 Length', 'Meta Description 1 Pixel Width',
#        'Meta Keyword 1', 'Meta Keywords 1 Length', 'H1-1', 'H1-1 length',
#        'H2-1', 'H2-1 length', 'H2-2', 'H2-2 length', 'Meta Robots 1',
#        'X-Robots-Tag 1', 'Meta Refresh 1', 'Canonical Link Element 1',
#        'rel="next" 1', 'rel="prev" 1', 'HTTP rel="next" 1',
#        'HTTP rel="prev" 1', 'Size (bytes)', 'Word Count', 'Text Ratio',
#        'Crawl Depth', 'Link Score', 'Inlinks', 'Unique Inlinks', '% of Total',
#        'Outlinks', 'Unique Outlinks', 'External Outlinks',
#        'Unique External Outlinks', 'Closest Similarity Match',
#        'No. Near Duplicates', 'Spelling Errors', 'Grammar Errors', 'Hash',
#        'Response Time', 'Last Modified', 'Redirect URL', 'Redirect Type',
#        'URL Encoded Address'],
#       dtype='object')

# %%
df1.describe()
# Out:
#        Status Code  Title 1 Length  Title 1 Pixel Width  \
# count   481.000000      481.000000           481.000000
# mean    201.696466       63.752599           601.056133
# std      13.058178       18.284645           173.301432
# min     200.000000        0.000000             0.000000
# 25%     200.000000       55.000000           512.000000
# 50%     200.000000       63.000000           594.000000
# 75%     200.000000       73.000000           689.000000
# max     302.000000      164.000000          1584.000000
#
#        Meta Description 1 Length  Meta Description 1 Pixel Width  \
# count                 481.000000                      481.000000
# mean                  181.920998                     1171.950104
# std                    49.252094                      316.576402
# min                     0.000000                        0.000000
# 25%                   159.000000                     1027.000000
# 50%                   178.000000                     1151.000000
# 75%                   201.000000                     1302.000000
# max                   441.000000                     2782.000000
#
#        Meta Keyword 1  Meta Keywords 1 Length  H1-1 length  H2-1 length  \
# count             0.0                   481.0   481.000000   481.000000
# mean              NaN                     0.0    34.168399    31.135135
# std               NaN                     0.0    21.326791    23.776223
# min               NaN                     0.0     0.000000     0.000000
# 25%               NaN                     0.0    19.000000    12.000000
# 50%               NaN                     0.0    31.000000    29.000000
# 75%               NaN                     0.0    45.000000    48.000000
# max               NaN                     0.0   140.000000   100.000000
#
#        H2-2 length  ...     Outlinks  Unique Outlinks  External Outlinks  \
# count   481.000000  ...   481.000000       481.000000         481.000000
# mean     22.817048  ...   816.158004       681.675676           6.091476
# std      23.629250  ...   295.525697       230.277167          32.927128
# min       0.000000  ...     0.000000         0.000000           0.000000
# 25%       0.000000  ...   610.000000       531.000000           3.000000
# 50%      20.000000  ...   721.000000       613.000000           3.000000
# 75%      41.000000  ...  1082.000000       862.000000           3.000000
# max      92.000000  ...  2255.000000      2035.000000         685.000000
#
#        Unique External Outlinks  Closest Similarity Match  \
# count                481.000000                       0.0
# mean                   5.995842                       NaN
# std                   32.509357                       NaN
# min                    0.000000                       NaN
# 25%                    3.000000                       NaN
# 50%                    3.000000                       NaN
# 75%                    3.000000                       NaN
# max                  679.000000                       NaN
#
#        No. Near Duplicates  Spelling Errors  Grammar Errors  Response Time  \
# count                  0.0              0.0             0.0     481.000000
# mean                   NaN              NaN             NaN       0.252699
# std                    NaN              NaN             NaN       0.158769
# min                    NaN              NaN             NaN       0.136000
# 25%                    NaN              NaN             NaN       0.171000
# 50%                    NaN              NaN             NaN       0.198000
# 75%                    NaN              NaN             NaN       0.268000
# max                    NaN              NaN             NaN       1.443000
#
#        Last Modified
# count            0.0
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
#
# [8 rows x 34 columns]

# %%
# Midbrain Academy dataset loading
df2 = pd.read_csv('midbrainacademy_data.csv')
df2.sample(5)
# Out:
#                                                Address     Content  \
# 419  http://midbrainacademy.in/midbrain-activation-...   text/html
# 175  https://midbrainacademy.in/midbrain-activation...   text/html
# 129       https://midbrainacademy.in/nlp-training.html   text/html
# 16   https://www.midbrainacademy.in/css/flexslider.css    text/css
# 320    https://midbrainacademy.in/photo-gallery/22.jpg  image/jpeg
#
#      Status Code Status Indexability Indexability Status  \
# 419          200     OK    Indexable                 NaN
# 175          200     OK    Indexable                 NaN
# 129          200     OK    Indexable                 NaN
# 16           200     OK    Indexable                 NaN
# 320          200     OK    Indexable                 NaN
#
#                                                Title 1  Title 1 Length  \
# 419   Midbrain Activation in Jabalpur - RAJMIN ACADEMY              48
# 175  Midbrain Activation in Bhubaneshwar - RAJMIN A...              52
# 129  NLP Training in India | Low Cost NLP Franchise...              55
# 16                                                 NaN               0
# 320                                                NaN               0
#
#      Title 1 Pixel Width                                 Meta Description 1  \
# 419                  462  Midbrain Activation in Jabalpur, Call us at +9...
# 175                  516  Midbrain Activation in Bhubaneshwar, Call us a...
# 129                  484  NLP Training in India - Find Low Cost NLP Fran...
# 16                     0                                                NaN
# 320                    0                                                NaN
#
#      ...  Closest Similarity Match  No. Near Duplicates Spelling Errors  \
# 419  ...                       NaN                  NaN             NaN
# 175  ...                       NaN                  NaN             NaN
# 129  ...                       NaN                  NaN             NaN
# 16   ...                       NaN                  NaN             NaN
# 320  ...                       NaN                  NaN             NaN
#
#      Grammar Errors                              Hash  Response Time  \
# 419             NaN   94be9943a0e684ffaafceaf7ca939c4          0.595
# 175             NaN  cd86628f519c5b62dd80231294698780          0.930
# 129             NaN  455e8f2d9f5592d4dda3fc12b79948f5          0.940
# 16              NaN                               NaN          1.000
# 320             NaN                               NaN          0.947
#
#                      Last Modified  Redirect URL Redirect Type  \
# 419  Sun, 15 Mar 2020 14:26:15 GMT           NaN           NaN
# 175  Sun, 15 Mar 2020 14:12:57 GMT           NaN           NaN
# 129  Thu, 12 Mar 2020 11:54:36 GMT           NaN           NaN
# 16   Wed, 11 Mar 2020 02:06:42 GMT           NaN           NaN
# 320  Wed, 11 Mar 2020 02:06:41 GMT           NaN           NaN
#
#                                    URL Encoded Address
# 419  http://midbrainacademy.in/midbrain-activation-...
# 175  https://midbrainacademy.in/midbrain-activation...
# 129       https://midbrainacademy.in/nlp-training.html
# 16   https://www.midbrainacademy.in/css/flexslider.css
# 320    https://midbrainacademy.in/photo-gallery/22.jpg
#
# [5 rows x 50 columns]

# %%
df2.shape
# Out:
# (444, 50)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Address                         444 non-null    object
#  1   Content                         444 non-null    object
#  2   Status Code                     444 non-null    int64
#  3   Status                          444 non-null    object
#  4   Indexability                    444 non-null    object
#  5   Indexability Status             99 non-null     object
#  6   Title 1                         182 non-null    object
#  7   Title 1 Length                  444 non-null    int64
#  8   Title 1 Pixel Width             444 non-null    int64
#  9   Meta Description 1              158 non-null    object
#  10  Meta Description 1 Length       444 non-null    int64
#  11  Meta Description 1 Pixel Width  444 non-null    int64
#  12  Meta Keyword 1                  98 non-null     object
#  13  Meta Keywords 1 Length          444 non-null    int64
#  14  H1-1                            182 non-null    object
#  15  H1-1 length                     444 non-null    int64
#  16  H2-1                            128 non-null    object
#  17  H2-1 length                     444 non-null    int64
#  18  H2-2                            109 non-null    object
#  19  H2-2 length                     444 non-null    int64
#  20  Meta Robots 1                   176 non-null    object
#  21  X-Robots-Tag 1                  0 non-null      float64
#  22  Meta Refresh 1                  0 non-null      float64
#  23  Canonical Link Element 1        0 non-null      float64
#  24  rel="next" 1                    0 non-null      float64
#  25  rel="prev" 1                    0 non-null      float64
#  26  HTTP rel="next" 1               0 non-null      float64
#  27  HTTP rel="prev" 1               0 non-null      float64
#  28  Size (bytes)                    444 non-null    int64
#  29  Word Count                      444 non-null    int64
#  30  Text Ratio                      444 non-null    float64
#  31  Crawl Depth                     444 non-null    int64
#  32  Link Score                      0 non-null      float64
#  33  Inlinks                         444 non-null    int64
#  34  Unique Inlinks                  444 non-null    int64
#  35  % of Total                      444 non-null    float64
#  36  Outlinks                        444 non-null    int64
#  37  Unique Outlinks                 444 non-null    int64
#  38  External Outlinks               444 non-null    int64
#  39  Unique External Outlinks        444 non-null    int64
#  40  Closest Similarity Match        0 non-null      float64
#  41  No. Near Duplicates             0 non-null      float64
#  42  Spelling Errors                 0 non-null      float64
#  43  Grammar Errors                  0 non-null      float64
#  44  Hash                            182 non-null    object
#  45  Response Time                   444 non-null    float64
#  46  Last Modified                   427 non-null    object
#  47  Redirect URL                    0 non-null      float64
#  48  Redirect Type                   0 non-null      float64
#  49  URL Encoded Address             444 non-null    object
# dtypes: float64(17), int64(18), object(15)
# memory usage: 173.6+ KB

# %%
df2.columns
# Out:
# Index(['Address', 'Content', 'Status Code', 'Status', 'Indexability',
#        'Indexability Status', 'Title 1', 'Title 1 Length',
#        'Title 1 Pixel Width', 'Meta Description 1',
#        'Meta Description 1 Length', 'Meta Description 1 Pixel Width',
#        'Meta Keyword 1', 'Meta Keywords 1 Length', 'H1-1', 'H1-1 length',
#        'H2-1', 'H2-1 length', 'H2-2', 'H2-2 length', 'Meta Robots 1',
#        'X-Robots-Tag 1', 'Meta Refresh 1', 'Canonical Link Element 1',
#        'rel="next" 1', 'rel="prev" 1', 'HTTP rel="next" 1',
#        'HTTP rel="prev" 1', 'Size (bytes)', 'Word Count', 'Text Ratio',
#        'Crawl Depth', 'Link Score', 'Inlinks', 'Unique Inlinks', '% of Total',
#        'Outlinks', 'Unique Outlinks', 'External Outlinks',
#        'Unique External Outlinks', 'Closest Similarity Match',
#        'No. Near Duplicates', 'Spelling Errors', 'Grammar Errors', 'Hash',
#        'Response Time', 'Last Modified', 'Redirect URL', 'Redirect Type',
#        'URL Encoded Address'],
#       dtype='object')

# %%
df2.describe()
# Out:
#        Status Code  Title 1 Length  Title 1 Pixel Width  \
# count   444.000000      444.000000           444.000000
# mean    238.556306       19.081081           177.108108
# std      79.909367       24.989437           230.393533
# min     200.000000        0.000000             0.000000
# 25%     200.000000        0.000000             0.000000
# 50%     200.000000        0.000000             0.000000
# 75%     200.000000       46.000000           433.000000
# max     404.000000       77.000000           727.000000
#
#        Meta Description 1 Length  Meta Description 1 Pixel Width  \
# count                 444.000000                      444.000000
# mean                   61.036036                      387.736486
# std                    84.273357                      534.954234
# min                     0.000000                        0.000000
# 25%                     0.000000                        0.000000
# 50%                     0.000000                        0.000000
# 75%                   161.000000                     1016.000000
# max                   216.000000                     1376.000000
#
#        Meta Keywords 1 Length  H1-1 length  H2-1 length  H2-2 length  \
# count              444.000000   444.000000   444.000000   444.000000
# mean                23.869369    12.211712    12.880631    11.047297
# std                 47.639742    17.222623    21.465110    21.478217
# min                  0.000000     0.000000     0.000000     0.000000
# 25%                  0.000000     0.000000     0.000000     0.000000
# 50%                  0.000000     0.000000     0.000000     0.000000
# 75%                  0.000000    23.000000    37.000000     0.000000
# max                158.000000    59.000000    81.000000    99.000000
#
#        X-Robots-Tag 1  ...  Unique Outlinks  External Outlinks  \
# count             0.0  ...       444.000000         444.000000
# mean              NaN  ...        24.628378           2.150901
# std               NaN  ...        30.042922           2.675400
# min               NaN  ...         0.000000           0.000000
# 25%               NaN  ...         0.000000           0.000000
# 50%               NaN  ...         0.000000           0.000000
# 75%               NaN  ...        60.000000           5.000000
# max               NaN  ...        72.000000           8.000000
#
#        Unique External Outlinks  Closest Similarity Match  \
# count                444.000000                       0.0
# mean                   2.137387                       NaN
# std                    2.648147                       NaN
# min                    0.000000                       NaN
# 25%                    0.000000                       NaN
# 50%                    0.000000                       NaN
# 75%                    5.000000                       NaN
# max                    8.000000                       NaN
#
#        No. Near Duplicates  Spelling Errors  Grammar Errors  Response Time  \
# count                  0.0              0.0             0.0     444.000000
# mean                   NaN              NaN             NaN       0.875867
# std                    NaN              NaN             NaN       0.157145
# min                    NaN              NaN             NaN       0.562000
# 25%                    NaN              NaN             NaN       0.892750
# 50%                    NaN              NaN             NaN       0.931000
# 75%                    NaN              NaN             NaN       0.959250
# max                    NaN              NaN             NaN       1.305000
#
#        Redirect URL  Redirect Type
# count           0.0            0.0
# mean            NaN            NaN
# std             NaN            NaN
# min             NaN            NaN
# 25%             NaN            NaN
# 50%             NaN            NaN
# 75%             NaN            NaN
# max             NaN            NaN
#
# [8 rows x 35 columns]

# %%
#mindadda dataset loading
df3 = pd.read_csv('mindadda_data.csv')
df3.sample(5)
# Out:
#                                                Address  \
# 53            http://mindadda.com/tag/english-grammar/
# 222  http://mindadda.com/tag/look-at-you-in-front-o...
# 228                   https://mindadda.com/tag/emails/
# 29                         http://mindadda.com/tag/pi/
# 101  https://mindadda.com/category/personality-deve...
#
#                       Content  Status Code Status Indexability  \
# 53   text/html; charset=UTF-8          200     OK    Indexable
# 222  text/html; charset=UTF-8          200     OK    Indexable
# 228  text/html; charset=UTF-8          200     OK    Indexable
# 29   text/html; charset=UTF-8          200     OK    Indexable
# 101  text/html; charset=UTF-8          200     OK    Indexable
#
#     Indexability Status                                            Title 1  \
# 53                  NaN  english grammar Archives | MindAdda - Your Emp...
# 222                 NaN  Look at you in front of mirror and encourage y...
# 228                 NaN  emails Archives | MindAdda - Your Empowerment ...
# 29                  NaN  pi Archives | MindAdda - Your Empowerment Part...
# 101                 NaN  Personality Development Archives | MindAdda - ...
#
#      Title 1 Length  Title 1 Pixel Width  \
# 53              123                 1150
# 222             161                 1466
# 228             114                 1061
# 29              110                 1020
# 101             131                 1222
#
#                                     Meta Description 1  ...  \
# 53                                                 NaN  ...
# 222                                                NaN  ...
# 228                                                NaN  ...
# 29                                                 NaN  ...
# 101  Welcome to the Smartest and Coolest community....  ...
#
#      Closest Similarity Match  No. Near Duplicates  Spelling Errors  \
# 53                        NaN                  NaN              NaN
# 222                       NaN                  NaN              NaN
# 228                       NaN                  NaN              NaN
# 29                        NaN                  NaN              NaN
# 101                       NaN                  NaN              NaN
#
#      Grammar Errors                              Hash  Response Time  \
# 53              NaN  44dabf86cefeb9fd45427e82c76be4ea          0.848
# 222             NaN  5d75ae6567570607881882ebfb11381f          0.835
# 228             NaN  e946b88b571e28873d7af661c319144d          3.057
# 29              NaN  89e994c69f6828eedba1a504410803e2          0.854
# 101             NaN  e034e8cf8bf5084199de04df132ac570          3.446
#
#                      Last Modified  Redirect URL Redirect Type  \
# 53   Sat, 18 Jul 2020 15:06:30 GMT           NaN           NaN
# 222  Sat, 18 Jul 2020 21:33:43 GMT           NaN           NaN
# 228  Sat, 18 Jul 2020 22:57:23 GMT           NaN           NaN
# 29   Sat, 18 Jul 2020 15:06:45 GMT           NaN           NaN
# 101  Sat, 18 Jul 2020 22:56:02 GMT           NaN           NaN
#
#                                    URL Encoded Address
# 53            http://mindadda.com/tag/english-grammar/
# 222  http://mindadda.com/tag/look-at-you-in-front-o...
# 228                   https://mindadda.com/tag/emails/
# 29                         http://mindadda.com/tag/pi/
# 101  https://mindadda.com/category/personality-deve...
#
# [5 rows x 51 columns]

# %%
df3.shape
# Out:
# (237, 51)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 51 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Address                         237 non-null    object
#  1   Content                         237 non-null    object
#  2   Status Code                     237 non-null    int64
#  3   Status                          237 non-null    object
#  4   Indexability                    237 non-null    object
#  5   Indexability Status             8 non-null      object
#  6   Title 1                         231 non-null    object
#  7   Title 1 Length                  237 non-null    int64
#  8   Title 1 Pixel Width             237 non-null    int64
#  9   Meta Description 1              80 non-null     object
#  10  Meta Description 1 Length       237 non-null    int64
#  11  Meta Description 1 Pixel Width  237 non-null    int64
#  12  Meta Keyword 1                  0 non-null      float64
#  13  Meta Keywords 1 Length          237 non-null    int64
#  14  H1-1                            216 non-null    object
#  15  H1-1 length                     237 non-null    int64
#  16  H2-1                            224 non-null    object
#  17  H2-1 length                     237 non-null    int64
#  18  H2-2                            101 non-null    object
#  19  H2-2 length                     237 non-null    int64
#  20  Meta Robots 1                   231 non-null    object
#  21  Meta Robots 2                   231 non-null    object
#  22  X-Robots-Tag 1                  0 non-null      float64
#  23  Meta Refresh 1                  0 non-null      float64
#  24  Canonical Link Element 1        231 non-null    object
#  25  rel="next" 1                    50 non-null     object
#  26  rel="prev" 1                    25 non-null     object
#  27  HTTP rel="next" 1               0 non-null      float64
#  28  HTTP rel="prev" 1               0 non-null      float64
#  29  Size (bytes)                    237 non-null    int64
#  30  Word Count                      237 non-null    int64
#  31  Text Ratio                      237 non-null    float64
#  32  Crawl Depth                     237 non-null    int64
#  33  Link Score                      0 non-null      float64
#  34  Inlinks                         237 non-null    int64
#  35  Unique Inlinks                  237 non-null    int64
#  36  % of Total                      237 non-null    float64
#  37  Outlinks                        237 non-null    int64
#  38  Unique Outlinks                 237 non-null    int64
#  39  External Outlinks               237 non-null    int64
#  40  Unique External Outlinks        237 non-null    int64
#  41  Closest Similarity Match        0 non-null      float64
#  42  No. Near Duplicates             0 non-null      float64
#  43  Spelling Errors                 0 non-null      float64
#  44  Grammar Errors                  0 non-null      float64
#  45  Hash                            231 non-null    object
#  46  Response Time                   237 non-null    float64
#  47  Last Modified                   229 non-null    object
#  48  Redirect URL                    3 non-null      object
#  49  Redirect Type                   3 non-null      object
#  50  URL Encoded Address             237 non-null    object
# dtypes: float64(13), int64(18), object(20)
# memory usage: 94.6+ KB

# %%
df3.columns
# Out:
# Index(['Address', 'Content', 'Status Code', 'Status', 'Indexability',
#        'Indexability Status', 'Title 1', 'Title 1 Length',
#        'Title 1 Pixel Width', 'Meta Description 1',
#        'Meta Description 1 Length', 'Meta Description 1 Pixel Width',
#        'Meta Keyword 1', 'Meta Keywords 1 Length', 'H1-1', 'H1-1 length',
#        'H2-1', 'H2-1 length', 'H2-2', 'H2-2 length', 'Meta Robots 1',
#        'Meta Robots 2', 'X-Robots-Tag 1', 'Meta Refresh 1',
#        'Canonical Link Element 1', 'rel="next" 1', 'rel="prev" 1',
#        'HTTP rel="next" 1', 'HTTP rel="prev" 1', 'Size (bytes)', 'Word Count',
#        'Text Ratio', 'Crawl Depth', 'Link Score', 'Inlinks', 'Unique Inlinks',
#        '% of Total', 'Outlinks', 'Unique Outlinks', 'External Outlinks',
#        'Unique External Outlinks', 'Closest Similarity Match',
#        'No. Near Duplicates', 'Spelling Errors', 'Grammar Errors', 'Hash',
#        'Response Time', 'Last Modified', 'Redirect URL', 'Redirect Type',
#        'URL Encoded Address'],
#       dtype='object')

# %%
df3.describe()
# Out:
#        Status Code  Title 1 Length  Title 1 Pixel Width  \
# count   237.000000      237.000000           237.000000
# mean    203.860759      106.683544           991.497890
# std      25.371678       38.753309           356.400016
# min     200.000000        0.000000             0.000000
# 25%     200.000000      112.000000          1047.000000
# 50%     200.000000      121.000000          1131.000000
# 75%     200.000000      126.000000          1168.000000
# max     404.000000      166.000000          1532.000000
#
#        Meta Description 1 Length  Meta Description 1 Pixel Width  \
# count                 237.000000                      237.000000
# mean                  260.215190                     1663.713080
# std                   507.043265                     3217.122231
# min                     0.000000                        0.000000
# 25%                     0.000000                        0.000000
# 50%                     0.000000                        0.000000
# 75%                   464.000000                     2970.000000
# max                  3503.000000                    22069.000000
#
#        Meta Keyword 1  Meta Keywords 1 Length  H1-1 length  H2-1 length  \
# count             0.0                   237.0   237.000000   237.000000
# mean              NaN                     0.0    17.202532    33.746835
# std               NaN                     0.0    12.645472    18.806644
# min               NaN                     0.0     0.000000     0.000000
# 25%               NaN                     0.0    11.000000    24.000000
# 50%               NaN                     0.0    15.000000    30.000000
# 75%               NaN                     0.0    20.000000    44.000000
# max               NaN                     0.0    59.000000   147.000000
#
#        H2-2 length  ...  % of Total    Outlinks  Unique Outlinks  \
# count   237.000000  ...  237.000000  237.000000       237.000000
# mean     14.780591  ...   14.393882   70.097046        35.687764
# std      19.469728  ...   17.673174   21.742208        11.834110
# min       0.000000  ...    0.000000    0.000000         0.000000
# 25%       0.000000  ...    5.190000   59.000000        29.000000
# 50%       0.000000  ...    6.930000   63.000000        33.000000
# 75%      30.000000  ...   12.990000   84.000000        44.000000
# max      59.000000  ...   66.230000  113.000000        62.000000
#
#        External Outlinks  Unique External Outlinks  Closest Similarity Match  \
# count         237.000000                237.000000                       0.0
# mean            8.949367                  7.894515                       NaN
# std             1.838146                  1.432615                       NaN
# min             0.000000                  0.000000                       NaN
# 25%             9.000000                  8.000000                       NaN
# 50%             9.000000                  8.000000                       NaN
# 75%             9.000000                  8.000000                       NaN
# max            19.000000                 14.000000                       NaN
#
#        No. Near Duplicates  Spelling Errors  Grammar Errors  Response Time
# count                  0.0              0.0             0.0     237.000000
# mean                   NaN              NaN             NaN       1.653418
# std                    NaN              NaN             NaN       1.324034
# min                    NaN              NaN             NaN       0.805000
# 25%                    NaN              NaN             NaN       0.868000
# 50%                    NaN              NaN             NaN       0.931000
# 75%                    NaN              NaN             NaN       1.702000
# max                    NaN              NaN             NaN       7.705000
#
# [8 rows x 31 columns]

# %% [markdown]
# #### MISSING column compared to other two datasets

# %%
#particular in mindadda data that not present in byjus data and midbrain academy
[i for i in df3.columns if i not in df1.columns and i not in df2.columns]
# Out:
# ['Meta Robots 2']

# %%
for i in df3['Meta Robots 2']:
    print(i)
# Out:
# nan
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# nan
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# nan
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# nan
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# nan
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# nan
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1
# index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1

# %% [markdown]
# # Picking important columns for further process

# %%
df1 = df1[['Address','Content', 'Status Code', 'Status','Title 1', 'Title 1 Length','Meta Description 1',\
           'Meta Description 1 Length','Meta Keyword 1', 'Meta Keywords 1 Length', 'H1-1','H1-1 length',\
           'H2-2', 'H2-2 length', 'Word Count', 'Text Ratio', 'Crawl Depth', 'Link Score', 'Inlinks', \
           'Unique Inlinks', '% of Total', 'Outlinks', 'Unique Outlinks', 'External Outlinks', \
           'Unique External Outlinks', 'Closest Similarity Match','Response Time']]

# %%
df1.sample(5)
# Out:
#                                                Address  \
# 466        https://byjus.com/cbse-notes/notes-class-9/
# 165  https://byjus.com/ncert-solutions-class-9-scie...
# 170                     https://byjus.com/calculators/
# 383  https://byjus.com/ncert-solutions-class-12-acc...
# 436         https://byjus.com/free-ias-prep/upsc-2020/
#
#                       Content  Status Code Status  \
# 466  text/html; charset=UTF-8          200     OK
# 165  text/html; charset=UTF-8          200     OK
# 170  text/html; charset=UTF-8          200     OK
# 383  text/html; charset=UTF-8          200     OK
# 436  text/html; charset=UTF-8          200     OK
#
#                                                Title 1  Title 1 Length  \
# 466         Notes For Class 9 CBSE - Free PDF Download              42
# 165  NCERT Solutions Class 9 Science Chapter 5 The ...              91
# 170  Free Online Calculators - Online Math, Physics...              69
# 383           NCERT Solutions For Class 12 Accountancy              40
# 436  UPSC 2020 - Download Free UPSC Books And Daily...              62
#
#                                     Meta Description 1  \
# 466  Notes For Class 9 CBSE is considered as one of...
# 165  NCERT Solutions Class 9 Science Chapter 5 The ...
# 170  Best Online Free ☑ Calculators - Best online c...
# 383  NCERT solutions for class 12 Accountancy conta...
# 436  UPSC 2020 - Check UPSC Exam Dates and Notifica...
#
#      Meta Description 1 Length  Meta Keyword 1  Meta Keywords 1 Length  ...  \
# 466                        134             NaN                       0  ...
# 165                        231             NaN                       0  ...
# 170                        159             NaN                       0  ...
# 383                        191             NaN                       0  ...
# 436                        259             NaN                       0  ...
#
#     Link Score  Inlinks Unique Inlinks  % of Total  Outlinks  Unique Outlinks  \
# 466        NaN      663            461       97.46      1061              851
# 165        NaN      493            461       97.46      1079              855
# 170        NaN      472            463       97.89       580              520
# 383        NaN      681            462       97.67      1106              869
# 436        NaN      500            465       98.31       883              767
#
#      External Outlinks  Unique External Outlinks  Closest Similarity Match  \
# 466                  3                         3                       NaN
# 165                  3                         3                       NaN
# 170                  7                         7                       NaN
# 383                  3                         3                       NaN
# 436                  4                         4                       NaN
#
#      Response Time
# 466          0.239
# 165          0.167
# 170          0.175
# 383          0.240
# 436          0.168
#
# [5 rows x 27 columns]

# %%
df2 = df2[['Address','Content', 'Status Code', 'Status','Title 1', 'Title 1 Length','Meta Description 1',\
           'Meta Description 1 Length','Meta Keyword 1', 'Meta Keywords 1 Length', 'H1-1','H1-1 length',\
           'H2-2', 'H2-2 length', 'Word Count', 'Text Ratio', 'Crawl Depth', 'Link Score', 'Inlinks', \
           'Unique Inlinks', '% of Total', 'Outlinks', 'Unique Outlinks', 'External Outlinks', \
           'Unique External Outlinks', 'Closest Similarity Match','Response Time']]

# %%
df2.sample(5)
# Out:
#                                                Address  \
# 101        https://www.midbrainacademy.in/Contact.html
# 53   https://midbrainacademy.in/Quantum-Speed-Readi...
# 401  http://midbrainacademy.in/Quantum-Speed-Readin...
# 282  https://www.midbrainacademy.in/blog/nlp-traini...
# 121  https://www.midbrainacademy.in/js/jquery.jcaro...
#
#                     Content  Status Code     Status  \
# 101               text/html          200         OK
# 53                text/html          200         OK
# 401               text/html          200         OK
# 282               text/html          404  Not Found
# 121  application/javascript          200         OK
#
#                                                Title 1  Title 1 Length  \
# 101     Midbrain Activation Academy Classes-Contact Us              46
# 53   QSR franchise | Training | Quantum Speed Readi...              67
# 401  QSR franchise | Training | Quantum Speed Readi...              67
# 282                                                NaN               0
# 121                                                NaN               0
#
#                                     Meta Description 1  \
# 101  Rajmin offering midbrain activation classes in...
# 53   Quantum Speed Reading Franchise - Looking for ...
# 401  Quantum Speed Reading Franchise - Looking for ...
# 282                                                NaN
# 121                                                NaN
#
#      Meta Description 1 Length  \
# 101                         98
# 53                         161
# 401                        161
# 282                          0
# 121                          0
#
#                                         Meta Keyword 1  \
# 101  Midbrain Activation Academy in jalandhar,chand...
# 53   quantum speed reading, speed reading, follow-u...
# 401  quantum speed reading, speed reading, follow-u...
# 282                                                NaN
# 121                                                NaN
#
#      Meta Keywords 1 Length  ... Link Score  Inlinks Unique Inlinks  \
# 101                      83  ...        NaN      266             72
# 53                      121  ...        NaN      167             58
# 401                     121  ...        NaN      158             53
# 282                       0  ...        NaN        1              1
# 121                       0  ...        NaN        0              0
#
#      % of Total  Outlinks  Unique Outlinks  External Outlinks  \
# 101       39.56        77               59                  5
# 53        31.87        92               60                  7
# 401       29.12        92               60                  7
# 282        0.55         0                0                  0
# 121        0.00         0                0                  0
#
#      Unique External Outlinks  Closest Similarity Match  Response Time
# 101                         5                       NaN          0.924
# 53                          7                       NaN          0.971
# 401                         7                       NaN          0.594
# 282                         0                       NaN          0.953
# 121                         0                       NaN          0.904
#
# [5 rows x 27 columns]

# %%
df3 = df3[['Address','Content', 'Status Code', 'Status','Title 1', 'Title 1 Length','Meta Description 1',\
           'Meta Description 1 Length','Meta Keyword 1', 'Meta Keywords 1 Length', 'H1-1','H1-1 length',\
           'H2-2', 'H2-2 length', 'Word Count', 'Text Ratio', 'Crawl Depth', 'Link Score', 'Inlinks', \
           'Unique Inlinks', '% of Total', 'Outlinks', 'Unique Outlinks', 'External Outlinks', \
           'Unique External Outlinks', 'Closest Similarity Match','Response Time']]

# %%
df3.sample(5)
# Out:
#                                                Address  \
# 75   http://mindadda.com/category/personality-devel...
# 146               http://mindadda.com/tag/influencers/
# 161         https://mindadda.com/tag/group-discussion/
# 177  http://mindadda.com/tag/effective-comprehensio...
# 138    http://mindadda.com/tag/personality-develpment/
#
#                       Content  Status Code Status  \
# 75   text/html; charset=UTF-8          200     OK
# 146  text/html; charset=UTF-8          200     OK
# 161  text/html; charset=UTF-8          200     OK
# 177  text/html; charset=UTF-8          200     OK
# 138  text/html; charset=UTF-8          200     OK
#
#                                                Title 1  Title 1 Length  \
# 75   Personality Development Archives | Page 2 of 7...             145
# 146  Influencers Archives | MindAdda - Your Empower...             119
# 161  group discussion Archives | MindAdda - Your Em...             124
# 177  Effective comprehension skills Archives | Mind...             138
# 138  Personality develpment Archives | MindAdda - Y...             130
#
#                                     Meta Description 1  \
# 75   Welcome to the Smartest and Coolest community....
# 146                                                NaN
# 161                                                NaN
# 177                                                NaN
# 138                                                NaN
#
#      Meta Description 1 Length  Meta Keyword 1  Meta Keywords 1 Length  ...  \
# 75                         558             NaN                       0  ...
# 146                          0             NaN                       0  ...
# 161                          0             NaN                       0  ...
# 177                          0             NaN                       0  ...
# 138                          0             NaN                       0  ...
#
#     Link Score  Inlinks Unique Inlinks  % of Total  Outlinks  Unique Outlinks  \
# 75         NaN        4              2        0.87        97               51
# 146        NaN       24             17        7.36       104               51
# 161        NaN       13             11        4.76        59               29
# 177        NaN       16             12        5.19        79               39
# 138        NaN       19             16        6.93        81               38
#
#      External Outlinks  Unique External Outlinks  Closest Similarity Match  \
# 75                   9                         8                       NaN
# 146                  9                         8                       NaN
# 161                  9                         8                       NaN
# 177                  9                         8                       NaN
# 138                  9                         8                       NaN
#
#      Response Time
# 75           1.161
# 146          1.282
# 161          4.124
# 177          0.923
# 138          0.911
#
# [5 rows x 27 columns]

# %% [markdown]
# # Title tag analaysis

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.scatter(df1['Title 1 Length'],range(0,len(df1['Title 1 Length'])),color='red')
ax1.set_title('byjus_Title 1 Lengths')

ax2 = fig.add_subplot(312)
ax2.scatter(df2['Title 1 Length'],range(0,len(df2['Title 1 Length'])),color='green')
ax2.set_title('midbrainacademy_Title 1 Lengths')

ax3 = fig.add_subplot(313)
ax3.scatter(df3['Title 1 Length'],range(0,len(df3['Title 1 Length'])),color='violet')
ax3.set_title('mindadda_Title 1 Lengths')

plt.show()

# %%
print("\n*************** BYJUS Title tag ANALYSIS ***************\n\n")
print('\tTotal count of title rows:\t',df1['Title 1 Length'].count())
print('\n\tAverage of title length:\t',df1[df1['Title 1 Length']>0]['Title 1 Length'].mean())
print('\n\tminimum value of title length:\t',df1['Title 1 Length'].min())
print('\n\tmaximum value of title length:\t',df1['Title 1 Length'].max())
print('\n\n','*'*60)
# Out:
# *************** BYJUS Title tag ANALYSIS ***************
#
#
# 	Total count of title rows:	 481
#
# 	Average of title length:	 64.83086680761099
#
# 	minimum value of title length:	 0
#
# 	maximum value of title length:	 164
#
#
#  ************************************************************

# %%
print("\n*************** MIDBRAINACADEMY Title tag ANALYSIS ***************\n\n")
print('\tTotal count of title rows:\t', df2['Title 1 Length'].count())
print('\n\tAverage of title length:\t', df2[df2['Title 1 Length']>0]['Title 1 Length'].mean())
print('\n\tminimum value of title length:\t', df2['Title 1 Length'].min())
print('\n\tmaximum value of title length:\t', df2['Title 1 Length'].max())
print('\n\n','*'*60)
# Out:
# *************** MIDBRAINACADEMY Title tag ANALYSIS ***************
#
#
# 	Total count of title rows:	 444
#
# 	Average of title length:	 46.54945054945055
#
# 	minimum value of title length:	 0
#
# 	maximum value of title length:	 77
#
#
#  ************************************************************

# %%
print("\n*************** MINDADDA Title tag ANALYSIS ***************\n\n")
print('\tTotal count of title rows:\t',df3['Title 1 Length'].count())
print('\n\tAverage of title length:\t',df3[df3['Title 1 Length']>0]['Title 1 Length'].mean())
print('\n\tminimum value of title length:\t',df3['Title 1 Length'].min())
print('\n\tmaximum value of title length:\t',df3['Title 1 Length'].max())
print('\n\n','*'*60)
# Out:
# *************** MINDADDA Title tag ANALYSIS ***************
#
#
# 	Total count of title rows:	 237
#
# 	Average of title length:	 109.45454545454545
#
# 	minimum value of title length:	 0
#
# 	maximum value of title length:	 166
#
#
#  ************************************************************

# %% [markdown]
# # Meta Description Analysis

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.scatter(df1['Meta Description 1 Length'],range(0,len(df1['Meta Description 1 Length'])),color='red')
ax1.set_title('byjus_meta_description_lengths')

ax2 = fig.add_subplot(312)
ax2.scatter(df2['Meta Description 1 Length'],range(0,len(df2['Meta Description 1 Length'])),color='green')
ax2.set_title('midbrainacademy_meta_description_lengths')

ax3 = fig.add_subplot(313)
ax3.scatter(df3['Meta Description 1 Length'],range(0,len(df3['Meta Description 1 Length'])),color='violet')
ax3.set_title('mindadda_meta_description_lengths')

plt.show()

# %%
print("\n*************** BYJUS META DESCRIPTION ANALYSIS ***************\n\n")
print('\tTotal count of meta description rows:\t',df1['Meta Description 1 Length'].count())
print('\n\tAverage of meta description length:\t',df1[df1['Meta Description 1 Length']>0]['Meta Description 1 Length'].mean())
print('\n\tminimum value of description length:\t',df1['Meta Description 1 Length'].min())
print('\n\tmaximum value of description length:\t',df1['Meta Description 1 Length'].max())
print('\n\n','*'*60)
# Out:
# *************** BYJUS META DESCRIPTION ANALYSIS ***************
#
#
# 	Total count of meta description rows:	 481
#
# 	Average of meta description length:	 185.78343949044586
#
# 	minimum value of description length:	 0
#
# 	maximum value of description length:	 441
#
#
#  ************************************************************

# %%
print("\n*************** MIDBRAIN ACADEMY META DESCRIPTION ANALYSIS ***************\n\n")
print('\tTotal count of meta description rows:\t',df2['Meta Description 1 Length'].count())
print('\n\tAverage of meta description length:\t',df2[df2['Meta Description 1 Length']>0]['Meta Description 1 Length'].mean())
print('\n\tminimum value of description length:\t',df2['Meta Description 1 Length'].min())
print('\n\tmaximum value of description length:\t',df2['Meta Description 1 Length'].max())
print('\n\n','*'*60)
# Out:
# *************** MIDBRAIN ACADEMY META DESCRIPTION ANALYSIS ***************
#
#
# 	Total count of meta description rows:	 444
#
# 	Average of meta description length:	 171.51898734177215
#
# 	minimum value of description length:	 0
#
# 	maximum value of description length:	 216
#
#
#  ************************************************************

# %%
print("\n*************** MINDADDA META DESCRIPTION ANALYSIS ***************\n\n")
print('\tTotal count of meta description rows:\t',df3['Meta Description 1 Length'].count())
print('\n\tAverage of meta description length:\t',df3[df3['Meta Description 1 Length']>0]['Meta Description 1 Length'].mean())
print('\n\tminimum value of description length:\t',df3['Meta Description 1 Length'].min())
print('\n\tmaximum value of description length:\t',df3['Meta Description 1 Length'].max())
print('\n\n','*'*60)
# Out:
# *************** MINDADDA META DESCRIPTION ANALYSIS ***************
#
#
# 	Total count of meta description rows:	 237
#
# 	Average of meta description length:	 770.8875
#
# 	minimum value of description length:	 0
#
# 	maximum value of description length:	 3503
#
#
#  ************************************************************

# %% [markdown]
# # Meta Keywords Analysis

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.scatter(df1['Meta Keywords 1 Length'],range(0,len(df1['Meta Keywords 1 Length'])),color='red')
ax1.set_title('byjus_Keywords_lengths')

ax2 = fig.add_subplot(312)
ax2.scatter(df2['Meta Keywords 1 Length'],range(0,len(df2['Meta Keywords 1 Length'])),color='green')
ax2.set_title('midbrainacademy_Keywords_lengths')

ax3 = fig.add_subplot(313)
ax3.scatter(df3['Meta Keywords 1 Length'],range(0,len(df3['Meta Keywords 1 Length'])),color='violet')
ax3.set_title('mindadda_Keywords_lengths')

plt.show()

# %%
df1['Meta Keywords 1 Length'].describe()
# Out:
# count    481.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: Meta Keywords 1 Length, dtype: float64

# %%
df2['Meta Keywords 1 Length'].describe()
# Out:
# count    444.000000
# mean      23.869369
# std       47.639742
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      158.000000
# Name: Meta Keywords 1 Length, dtype: float64

# %%
df3['Meta Keywords 1 Length'].describe()
# Out:
# count    237.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: Meta Keywords 1 Length, dtype: float64

# %%
df2.sample(5)
# Out:
#                                                Address  \
# 159  https://www.midbrainacademy.in/midbrain-activa...
# 415              http://midbrainacademy.in/js/utils.js
# 232  https://www.midbrainacademy.in/blog/best-time-...
# 351    https://midbrainacademy.in/photo-gallery/15.jpg
# 186         https://midbrainacademy.in/brain-wave.html
#
#                            Content  Status Code     Status  \
# 159  text/html; charset=iso-8859-1          403  Forbidden
# 415         application/javascript          200         OK
# 232                      text/html          404  Not Found
# 351                     image/jpeg          200         OK
# 186                      text/html          200         OK
#
#                                                Title 1  Title 1 Length  \
# 159                                                NaN               0
# 415                                                NaN               0
# 232                                                NaN               0
# 351                                                NaN               0
# 186  Enlarge Brain Waves with Rajmin Academy in Pun...              56
#
#                                     Meta Description 1  \
# 159                                                NaN
# 415                                                NaN
# 232                                                NaN
# 351                                                NaN
# 186  Enlarge your brainwaves and expand your abilit...
#
#      Meta Description 1 Length Meta Keyword 1  Meta Keywords 1 Length  ...  \
# 159                          0            NaN                       0  ...
# 415                          0            NaN                       0  ...
# 232                          0            NaN                       0  ...
# 351                          0            NaN                       0  ...
# 186                        169            NaN                       0  ...
#
#     Link Score  Inlinks Unique Inlinks  % of Total  Outlinks  Unique Outlinks  \
# 159        NaN       18             18        9.89         0                0
# 415        NaN        0              0        0.00         0                0
# 232        NaN        1              1        0.55         0                0
# 351        NaN        1              1        0.55         0                0
# 186        NaN       58             54       29.67        91               60
#
#      External Outlinks  Unique External Outlinks  Closest Similarity Match  \
# 159                  0                         0                       NaN
# 415                  0                         0                       NaN
# 232                  0                         0                       NaN
# 351                  0                         0                       NaN
# 186                  5                         5                       NaN
#
#      Response Time
# 159          0.919
# 415          0.620
# 232          0.927
# 351          0.919
# 186          0.920
#
# [5 rows x 27 columns]

# %% [markdown]
# # H1 Tag Analysis

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.scatter(df1['H1-1 length'],range(0,len(df1['H1-1 length'])),color='red')
ax1.set_title('byjus_h1_lengths')

ax2 = fig.add_subplot(312)
ax2.scatter(df2['H1-1 length'],range(0,len(df2['H1-1 length'])),color='green')
ax2.set_title('midbrainacademy_h1_lengths')

ax3 = fig.add_subplot(313)
ax3.scatter(df3['H1-1 length'],range(0,len(df3['H1-1 length'])),color='violet')
ax3.set_title('mindadda_h1_lengths')

plt.show()

# %%
print("\n*************** BYJUS H1 tag ANALYSIS ***************\n\n")
print('\tTotal count of H1 rows:\t\t',df1['H1-1 length'].count())
print('\n\tAverage of H1 length:\t\t',df1[df1['H1-1 length']>0]['H1-1 length'].mean())
print('\n\tminimum value of H1 length:\t',df1['H1-1 length'].min())
print('\n\tmaximum value of H1 length:\t',df1['H1-1 length'].max())
print('\n\n','*'*60)
# Out:
# *************** BYJUS H1 tag ANALYSIS ***************
#
#
# 	Total count of H1 rows:		 481
#
# 	Average of H1 length:		 35.72826086956522
#
# 	minimum value of H1 length:	 0
#
# 	maximum value of H1 length:	 140
#
#
#  ************************************************************

# %%
print("\n*************** MIDBRAIN ACADEMY H1 tag ANALYSIS ***************\n\n")
print('\tTotal count of H1 rows:\t\t',df2['H1-1 length'].count())
print('\n\tAverage of H1 length:\t\t',df2[df2['H1-1 length']>0]['H1-1 length'].mean())
print('\n\tminimum value of H1 length:\t',df2['H1-1 length'].min())
print('\n\tmaximum value of H1 length:\t',df2['H1-1 length'].max())
print('\n\n','*'*60)
# Out:
# *************** MIDBRAIN ACADEMY H1 tag ANALYSIS ***************
#
#
# 	Total count of H1 rows:		 444
#
# 	Average of H1 length:		 29.791208791208792
#
# 	minimum value of H1 length:	 0
#
# 	maximum value of H1 length:	 59
#
#
#  ************************************************************

# %%
print("\n*************** MINDADDA H1 tag ANALYSIS ***************\n\n")
print('\tTotal count of H1 rows:\t\t',df3['H1-1 length'].count())
print('\n\tAverage of H1 length:\t\t',df3[df3['H1-1 length']>0]['H1-1 length'].mean())
print('\n\tminimum value of H1 length:\t',df3['H1-1 length'].min())
print('\n\tmaximum value of H1 length:\t',df3['H1-1 length'].max())
print('\n\n','*'*60)
# Out:
# *************** MINDADDA H1 tag ANALYSIS ***************
#
#
# 	Total count of H1 rows:		 237
#
# 	Average of H1 length:		 18.875
#
# 	minimum value of H1 length:	 0
#
# 	maximum value of H1 length:	 59
#
#
#  ************************************************************

# %% [markdown]
# # H2 Tag Analysis

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.scatter(df1['H2-2 length'],range(0,len(df1['H2-2 length'])),color='red')
ax1.set_title('byjus_h2_lengths')

ax2 = fig.add_subplot(312)
ax2.scatter(df2['H2-2 length'],range(0,len(df2['H2-2 length'])),color='green')
ax2.set_title('midbrainacademy_h2_lengths')

ax3 = fig.add_subplot(313)
ax3.scatter(df3['H2-2 length'],range(0,len(df3['H2-2 length'])),color='violet')
ax3.set_title('mindadda_h2_lengths')

plt.show()

# %%
print("\n*************** BYJUS H2 tag ANALYSIS ***************\n\n")
print('\tTotal count of H2 rows:\t\t',df1['H2-2 length'].count())
print('\n\tAverage of H2 length:\t\t',df1[df1['H2-2 length']>0]['H2-2 length'].mean())
print('\n\tminimum value of H2 length:\t',df1['H2-2 length'].min())
print('\n\tmaximum value of H2 length:\t',df1['H2-2 length'].max())
print('\n\n','*'*60)
# Out:
# *************** BYJUS H2 tag ANALYSIS ***************
#
#
# 	Total count of H2 rows:		 481
#
# 	Average of H2 length:		 38.50877192982456
#
# 	minimum value of H2 length:	 0
#
# 	maximum value of H2 length:	 92
#
#
#  ************************************************************

# %%
print("\n*************** MIDBRAIN ACADEMY H2 tag ANALYSIS ***************\n\n")
print('\tTotal count of H2 rows:\t\t',df2['H2-2 length'].count())
print('\n\tAverage of H2 length:\t\t',df2[df2['H2-2 length']>0]['H2-2 length'].mean())
print('\n\tminimum value of H2 length:\t',df2['H2-2 length'].min())
print('\n\tmaximum value of H2 length:\t',df2['H2-2 length'].max())
print('\n\n','*'*60)
# Out:
# *************** MIDBRAIN ACADEMY H2 tag ANALYSIS ***************
#
#
# 	Total count of H2 rows:		 444
#
# 	Average of H2 length:		 45.0
#
# 	minimum value of H2 length:	 0
#
# 	maximum value of H2 length:	 99
#
#
#  ************************************************************

# %%
print("\n*************** MINDADDA H2 tag ANALYSIS ***************\n\n")
print('\tTotal count of H2 rows:\t\t',df3['H2-2 length'].count())
print('\n\tAverage of H2 length:\t\t',df3[df3['H2-2 length']>0]['H2-2 length'].mean())
print('\n\tminimum value of H2 length:\t',df3['H2-2 length'].min())
print('\n\tmaximum value of H2 length:\t',df3['H2-2 length'].max())
print('\n\n','*'*60)
# Out:
# *************** MINDADDA H2 tag ANALYSIS ***************
#
#
# 	Total count of H2 rows:		 237
#
# 	Average of H2 length:		 34.68316831683168
#
# 	minimum value of H2 length:	 0
#
# 	maximum value of H2 length:	 59
#
#
#  ************************************************************

# %%
df2.sample(5)
# Out:
#                                                Address  \
# 262  https://www.midbrainacademy.in/midbrain-activa...
# 352          http://midbrainacademy.in/images/home.png
# 348           http://midbrainacademy.in/css/camera.css
# 412    https://midbrainacademy.in/photo-gallery/21.jpg
# 196            https://midbrainacademy.in/js/jquery.js
#
#                            Content  Status Code     Status Title 1  \
# 262  text/html; charset=iso-8859-1          403  Forbidden     NaN
# 352                      image/png          200         OK     NaN
# 348                       text/css          200         OK     NaN
# 412                     image/jpeg          200         OK     NaN
# 196         application/javascript          200         OK     NaN
#
#      Title 1 Length Meta Description 1  Meta Description 1 Length  \
# 262               0                NaN                          0
# 352               0                NaN                          0
# 348               0                NaN                          0
# 412               0                NaN                          0
# 196               0                NaN                          0
#
#     Meta Keyword 1  Meta Keywords 1 Length  ... Link Score  Inlinks  \
# 262            NaN                       0  ...        NaN       18
# 352            NaN                       0  ...        NaN        0
# 348            NaN                       0  ...        NaN        0
# 412            NaN                       0  ...        NaN        1
# 196            NaN                       0  ...        NaN        0
#
#     Unique Inlinks  % of Total  Outlinks  Unique Outlinks  External Outlinks  \
# 262             18        9.89         0                0                  0
# 352              0        0.00         0                0                  0
# 348              0        0.00         0                0                  0
# 412              1        0.55         0                0                  0
# 196              0        0.00         0                0                  0
#
#      Unique External Outlinks  Closest Similarity Match  Response Time
# 262                         0                       NaN          0.949
# 352                         0                       NaN          0.595
# 348                         0                       NaN          0.582
# 412                         0                       NaN          0.948
# 196                         0                       NaN          0.891
#
# [5 rows x 27 columns]

# %% [markdown]
# # Inlinks Analysis

# %% [markdown]
# ### Inlinks = Links on other websites that send traffic to your site.
# <br/><br/>
# <li>Also called "backlinks". </li>
# <li>Traditionally Google has counted them as "votes" for your site, so that they help your site's Google rankings and traffic. </li>

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.scatter(df1['Inlinks'],range(0,len(df1['Inlinks'])),color='red')
ax1.set_title('byjus_Inlinks ')

ax2 = fig.add_subplot(312)
ax2.scatter(df2['Inlinks'],range(0,len(df2['Inlinks'])),color='green')
ax2.set_title('midbrainacademy_Inlinks ')

ax3 = fig.add_subplot(313)
ax3.scatter(df3['Inlinks'],range(0,len(df3['Inlinks'])),color='violet')
ax3.set_title('mindadda_Inlinks ')

plt.show()

# %%
print("\n*************** BYJUS Inlinks ANALYSIS ***************\n\n")
print('\tTotal count of Inlinks rows:\t',df1['Inlinks'].count())
print('\n\tAverage of Inlinks:\t\t',df1[df1['Inlinks']>0]['Inlinks'].mean())
print('\n\tminimum value of Inlinks:\t',df1['Inlinks'].min())
print('\n\tmaximum value of Inlinks:\t',df1['Inlinks'].max())
print('\n\n','*'*60)
# Out:
# *************** BYJUS Inlinks ANALYSIS ***************
#
#
# 	Total count of Inlinks rows:	 481
#
# 	Average of Inlinks:		 513.4968814968815
#
# 	minimum value of Inlinks:	 1
#
# 	maximum value of Inlinks:	 1397
#
#
#  ************************************************************

# %%
print("\n*************** MIDBRAIN ACADEMY Inlinks ANALYSIS ***************\n\n")
print('\tTotal count of Inlinks rows:\t',df2['Inlinks'].count())
print('\n\tAverage of Inlinks:\t\t',df2[df2['Inlinks']>0]['Inlinks'].mean())
print('\n\tminimum value of Inlinks:\t',df2['Inlinks'].min())
print('\n\tmaximum value of Inlinks:\t',df2['Inlinks'].max())
print('\n\n','*'*60)
# Out:
# *************** MIDBRAIN ACADEMY Inlinks ANALYSIS ***************
#
#
# 	Total count of Inlinks rows:	 444
#
# 	Average of Inlinks:		 58.56678700361011
#
# 	minimum value of Inlinks:	 0
#
# 	maximum value of Inlinks:	 266
#
#
#  ************************************************************

# %%
print("\n*************** MINDADDA Inlinks ANALYSIS ***************\n\n")
print('\tTotal count of Inlinks rows:\t',df3['Inlinks'].count())
print('\n\tAverage of Inlinks:\t\t',df3[df3['Inlinks']>0]['Inlinks'].mean())
print('\n\tminimum value of Inlinks:\t',df3['Inlinks'].min())
print('\n\tmaximum value of Inlinks:\t',df3['Inlinks'].max())
print('\n\n','*'*60)
# Out:
# *************** MINDADDA Inlinks ANALYSIS ***************
#
#
# 	Total count of Inlinks rows:	 237
#
# 	Average of Inlinks:		 67.0042372881356
#
# 	minimum value of Inlinks:	 0
#
# 	maximum value of Inlinks:	 656
#
#
#  ************************************************************

# %%
df1.sample(5)
# Out:
#                                               Address  \
# 313        https://byjus.com/ncert-books-for-class-5/
# 222                     https://byjus.com/disclaimer/
# 48               https://byjus.com/maths/probability/
# 37   https://byjus.com/ncert-solutions-class-6-maths/
# 220              https://byjus.com/ias/upsc-syllabus/
#
#                       Content  Status Code Status  \
# 313  text/html; charset=UTF-8          200     OK
# 222  text/html; charset=UTF-8          200     OK
# 48   text/html; charset=UTF-8          200     OK
# 37   text/html; charset=UTF-8          200     OK
# 220  text/html; charset=UTF-8          200     OK
#
#                                                Title 1  Title 1 Length  \
# 313  NCERT Books For Class 5 All Subjects - Downloa...              57
# 222                                Disclaimer - BYJU'S              19
# 48   Probability in Maths- Definition, Formula, Typ...              70
# 37        NCERT Solutions For Class 6 Maths - Free PDF              44
# 220  IAS Syllabus 2020 - Download UPSC Syllabus PDF...              68
#
#                                     Meta Description 1  \
# 313  NCERT Books class 5 for all Subjects are provi...
# 222  The information is provided by Think & Learn P...
# 48   Probability means the possibility that an even...
# 37   NCERT Solutions for Class 6 Maths PDFs of 2020...
# 220  UPSC (Union Public Service Commission) sets th...
#
#      Meta Description 1 Length  Meta Keyword 1  Meta Keywords 1 Length  ...  \
# 313                        198             NaN                       0  ...
# 222                        237             NaN                       0  ...
# 48                         175             NaN                       0  ...
# 37                         170             NaN                       0  ...
# 220                        246             NaN                       0  ...
#
#     Link Score  Inlinks Unique Inlinks  % of Total  Outlinks  Unique Outlinks  \
# 313        NaN      668            462       97.67      1167              960
# 222        NaN      468            467       98.73       525              472
# 48         NaN        9              4        0.85       673              579
# 37         NaN      683            462       97.67      1172              944
# 220        NaN     1022            466       98.52       740              618
#
#      External Outlinks  Unique External Outlinks  Closest Similarity Match  \
# 313                  9                         9                       NaN
# 222                  7                         7                       NaN
# 48                   3                         3                       NaN
# 37                   3                         3                       NaN
# 220                  7                         7                       NaN
#
#      Response Time
# 313          0.249
# 222          0.272
# 48           0.193
# 37           0.176
# 220          0.177
#
# [5 rows x 27 columns]

# %% [markdown]
# # Crawl Depth Analysis
#    ### Crawl depth is the extent to which a search engine indexes pages within a website.

# %% [markdown]
# <img src="data:image/jpeg;base64,..."/>

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.bar(df1['Crawl Depth'],range(0,len(df1['Crawl Depth'])),color='red')
ax1.set_title('byjus_Crawl Depth ')

ax2 = fig.add_subplot(312)
ax2.bar(df2['Crawl Depth'],range(0,len(df2['Crawl Depth'])),color='green')
ax2.set_title('midbrainacademy_Crawl Depth ')

ax3 = fig.add_subplot(313)
ax3.bar(df3['Crawl Depth'],range(0,len(df3['Crawl Depth'])),color='violet')
ax3.set_title('mindadda_Crawl Depth ')


plt.show()

# %%
print("\n*************** BYJUS Crawl Depth ANALYSIS ***************\n\n")
print('\tTotal count of Crawl Depth rows:\t',df1['Crawl Depth'].count())
print('\n\tAverage of Crawl Depth:\t\t\t',df1[df1['Crawl Depth']>0]['Crawl Depth'].mean())
print('\n\tminimum value of Crawl Depth:\t\t',df1['Crawl Depth'].min())
print('\n\tmaximum value of Crawl Depth:\t\t',df1['Crawl Depth'].max())
print('\n\n','*'*60)
# Out:
# *************** BYJUS Crawl Depth ANALYSIS ***************
#
#
# 	Total count of Crawl Depth rows:	 481
#
# 	Average of Crawl Depth:			 1.0729166666666667
#
# 	minimum value of Crawl Depth:		 0
#
# 	maximum value of Crawl Depth:		 2
#
#
#  ************************************************************

# %%
print("\n*************** MIDBRAIN ACADEMY Crawl Depth ANALYSIS ***************\n\n")
print('\tTotal count of Crawl Depth rows:\t',df2['Crawl Depth'].count())
print('\n\tAverage of Crawl Depth:\t\t\t',df2[df2['Crawl Depth']>0]['Crawl Depth'].mean())
print('\n\tminimum value of Crawl Depth:\t\t',df2['Crawl Depth'].min())
print('\n\tmaximum value of Crawl Depth:\t\t',df2['Crawl Depth'].max())
print('\n\n','*'*60)
# Out:
# *************** MIDBRAIN ACADEMY Crawl Depth ANALYSIS ***************
#
#
# 	Total count of Crawl Depth rows:	 444
#
# 	Average of Crawl Depth:			 2.0632054176072234
#
# 	minimum value of Crawl Depth:		 0
#
# 	maximum value of Crawl Depth:		 3
#
#
#  ************************************************************

# %%
print("\n*************** MINDADDA Crawl Depth ANALYSIS ***************\n\n")
print('\tTotal count of Crawl Depth rows:\t',df3['Crawl Depth'].count())
print('\n\tAverage of Crawl Depth:\t\t\t',df3[df3['Crawl Depth']>0]['Crawl Depth'].mean())
print('\n\tminimum value of Crawl Depth:\t\t',df3['Crawl Depth'].min())
print('\n\tmaximum value of Crawl Depth:\t\t',df3['Crawl Depth'].max())
print('\n\n','*'*60)
# Out:
# *************** MINDADDA Crawl Depth ANALYSIS ***************
#
#
# 	Total count of Crawl Depth rows:	 237
#
# 	Average of Crawl Depth:			 3.330508474576271
#
# 	minimum value of Crawl Depth:		 0
#
# 	maximum value of Crawl Depth:		 4
#
#
#  ************************************************************

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Address                    444 non-null    object
#  1   Content                    444 non-null    object
#  2   Status Code                444 non-null    int64
#  3   Status                     444 non-null    object
#  4   Title 1                    182 non-null    object
#  5   Title 1 Length             444 non-null    int64
#  6   Meta Description 1         158 non-null    object
#  7   Meta Description 1 Length  444 non-null    int64
#  8   Meta Keyword 1             98 non-null     object
#  9   Meta Keywords 1 Length     444 non-null    int64
#  10  H1-1                       182 non-null    object
#  11  H1-1 length                444 non-null    int64
#  12  H2-2                       109 non-null    object
#  13  H2-2 length                444 non-null    int64
#  14  Word Count                 444 non-null    int64
#  15  Text Ratio                 444 non-null    float64
#  16  Crawl Depth                444 non-null    int64
#  17  Link Score                 0 non-null      float64
#  18  Inlinks                    444 non-null    int64
#  19  Unique Inlinks             444 non-null    int64
#  20  % of Total                 444 non-null    float64
#  21  Outlinks                   444 non-null    int64
#  22  Unique Outlinks            444 non-null    int64
#  23  External Outlinks          444 non-null    int64
#  24  Unique External Outlinks   444 non-null    int64
#  25  Closest Similarity Match   0 non-null      float64
#  26  Response Time              444 non-null    float64
# dtypes: float64(5), int64(14), object(8)
# memory usage: 93.8+ KB

# %% [markdown]
# # Outlinks Analysis
# ### Outlinks” shows the list of external URLs that were clicked by our visitors from our website pages.

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.scatter(df1['Outlinks'],range(0,len(df1['Outlinks'])),color='red')
ax1.set_title('byjus_Outlinks ')

ax2 = fig.add_subplot(312)
ax2.scatter(df2['Outlinks'],range(0,len(df2['Outlinks'])),color='green')
ax2.set_title('midbrainacademy_Outlinks ')

ax3 = fig.add_subplot(313)
ax3.scatter(df3['Outlinks'],range(0,len(df3['Outlinks'])),color='violet')
ax3.set_title('mindadda_Outlinks ')

plt.show()

# %%
print("\n*************** BYJUS Outlinks ANALYSIS ***************\n\n")
print('\tTotal count of Outlinks rows :\t',df1['Outlinks'].count())
print('\n\tAverage of Outlinks :\t\t',df1[df1['Outlinks']>0]['Outlinks'].mean())
print('\n\tminimum value of Outlinks :\t',df1['Outlinks'].min())
print('\n\tmaximum value of Outlinks :\t',df1['Outlinks'].max())
print('\n\n','*'*60)
# Out:
# *************** BYJUS Outlinks ANALYSIS ***************
#
#
# 	Total count of Outlinks rows :	 481
#
# 	Average of Outlinks :		 833.4861995753715
#
# 	minimum value of Outlinks :	 0
#
# 	maximum value of Outlinks :	 2255
#
#
#  ************************************************************

# %%
print("\n*************** MIDBRAIN ACADEMY Outlinks ANALYSIS ***************\n\n")
print('\tTotal count of Outlinks rows:\t',df2['Outlinks'].count())
print('\n\tAverage of Outlinks :\t\t',df2[df2['Outlinks']>0]['Outlinks'].mean())
print('\n\tminimum value of Outlinks :\t',df2['Outlinks'].min())
print('\n\tmaximum value of Outlinks :\t',df2['Outlinks'].max())
print('\n\n','*'*60)
# Out:
# *************** MIDBRAIN ACADEMY Outlinks ANALYSIS ***************
#
#
# 	Total count of Outlinks rows:	 444
#
# 	Average of Outlinks :		 91.11731843575419
#
# 	minimum value of Outlinks :	 0
#
# 	maximum value of Outlinks :	 103
#
#
#  ************************************************************

# %%
print("\n*************** MINDADDA Outlinks ANALYSIS ***************\n\n")
print('\tTotal count of Outlinks rows:\t',df3['Outlinks'].count())
print('\n\tAverage of Outlinks :\t\t',df3[df3['Outlinks']>0]['Outlinks'].mean())
print('\n\tminimum value of Outlinks :\t',df3['Outlinks'].min())
print('\n\tmaximum value of Outlinks :\t',df3['Outlinks'].max())
print('\n\n','*'*60)
# Out:
# *************** MINDADDA Outlinks ANALYSIS ***************
#
#
# 	Total count of Outlinks rows:	 237
#
# 	Average of Outlinks :		 71.91774891774892
#
# 	minimum value of Outlinks :	 0
#
# 	maximum value of Outlinks :	 113
#
#
#  ************************************************************

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Address                    481 non-null    object
#  1   Content                    481 non-null    object
#  2   Status Code                481 non-null    int64
#  3   Status                     481 non-null    object
#  4   Title 1                    473 non-null    object
#  5   Title 1 Length             481 non-null    int64
#  6   Meta Description 1         471 non-null    object
#  7   Meta Description 1 Length  481 non-null    int64
#  8   Meta Keyword 1             0 non-null      float64
#  9   Meta Keywords 1 Length     481 non-null    int64
#  10  H1-1                       460 non-null    object
#  11  H1-1 length                481 non-null    int64
#  12  H2-2                       285 non-null    object
#  13  H2-2 length                481 non-null    int64
#  14  Word Count                 481 non-null    int64
#  15  Text Ratio                 481 non-null    float64
#  16  Crawl Depth                481 non-null    int64
#  17  Link Score                 0 non-null      float64
#  18  Inlinks                    481 non-null    int64
#  19  Unique Inlinks             481 non-null    int64
#  20  % of Total                 481 non-null    float64
#  21  Outlinks                   481 non-null    int64
#  22  Unique Outlinks            481 non-null    int64
#  23  External Outlinks          481 non-null    int64
#  24  Unique External Outlinks   481 non-null    int64
#  25  Closest Similarity Match   0 non-null      float64
#  26  Response Time              481 non-null    float64
# dtypes: float64(6), int64(14), object(7)
# memory usage: 101.6+ KB

# %% [markdown]
# # Response Time Analysis

# %% [markdown]
# Response time : In website monitoring, response time is calculated as the total time taken to resolve the DNS, complete the TCP hand-shake, negotiate an SSL handshake (for HTTPS) and download the full HTML output from the server

# %% [markdown]
# ### What is a good response time for a website?

# %% [markdown]
# Average page size: 1.56MB; As you can see the location you are accessing the website plays a significant role in the response time, but the average is around 3.5 seconds. “The lower, the better” rule applies here as well, of course, but if your site is able to fully load under 2 seconds, that is a great result.

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)
ax1.scatter(df1['Response Time'],range(0,len(df1['Response Time'])),color='red')
ax1.set_title('byjus_Response Time')

ax2 = fig.add_subplot(312)
ax2.scatter(df2['Response Time'],range(0,len(df2['Response Time'])),color='green')
ax2.set_title('midbrainacademy_Response Time ')

ax3 = fig.add_subplot(313)
ax3.scatter(df3['Response Time'],range(0,len(df3['Response Time'])),color='violet')
ax3.set_title('mindadda_Response Time ')

plt.show()

# %%
print("\n*************** BYJUS Response Time ANALYSIS ***************\n\n")
print('\tTotal count of Response Time rows:\t',df1['Response Time'].count())
print('\n\tAverage of Response Time :\t\t',df1[df1['Response Time']>0]['Response Time'].mean())
print('\n\tminimum value of Response Time :\t',df1['Response Time'].min())
print('\n\tmaximum value of Response Time :\t',df1['Response Time'].max())
print('\n\n','*'*60)
# Out:
# *************** BYJUS Response Time ANALYSIS ***************
#
#
# 	Total count of Response Time rows:	 481
#
# 	Average of Response Time :		 0.25269854469854497
#
# 	minimum value of Response Time :	 0.136
#
# 	maximum value of Response Time :	 1.443
#
#
#  ************************************************************

# %%
print("\n*************** MIDBRAIN ACADEMY Response Time ANALYSIS ***************\n\n")
print('\tTotal count of Response Time rows :\t',df2['Response Time'].count())
print('\n\tAverage of Response Time :\t\t',df2[df2['Response Time']>0]['Response Time'].mean())
print('\n\tminimum value of Response Time :\t',df2['Response Time'].min())
print('\n\tmaximum value of Response Time :\t',df2['Response Time'].max())
print('\n\n','*'*60)
# Out:
# *************** MIDBRAIN ACADEMY Response Time ANALYSIS ***************
#
#
# 	Total count of Response Time rows :	 444
#
# 	Average of Response Time :		 0.8758671171171174
#
# 	minimum value of Response Time :	 0.562
#
# 	maximum value of Response Time :	 1.305
#
#
#  ************************************************************

# %%
print("\n*************** MINDADDA Response Time ANALYSIS ***************\n\n")
print('\tTotal count of Response Time rows:\t',df3['Response Time'].count())
print('\n\tAverage of Response Time :\t\t',df3[df3['Response Time']>0]['Response Time'].mean())
print('\n\tminimum value of Response Time :\t',df3['Response Time'].min())
print('\n\tmaximum value of Response Time :\t',df3['Response Time'].max())
print('\n\n','*'*60)
# Out:
# *************** MINDADDA Response Time ANALYSIS ***************
#
#
# 	Total count of Response Time rows:	 237
#
# 	Average of Response Time :		 1.6534177215189865
#
# 	minimum value of Response Time :	 0.805
#
# 	maximum value of Response Time :	 7.705
#
#
#  ************************************************************

# %%
mldf =  df1[['Title 1 Length', 'Meta Description 1 Length','H1-1 length',\
             'H2-2 length', 'Word Count', 'Text Ratio', 'Crawl Depth','Response Time']]

# %%
mldf.isnull().sum()
# Out:
# Title 1 Length               0
# Meta Description 1 Length    0
# H1-1 length                  0
# H2-2 length                  0
# Word Count                   0
# Text Ratio                   0
# Crawl Depth                  0
# Response Time                0
# dtype: int64

# %%
x = mldf[['Title 1 Length', 'Meta Description 1 Length','H1-1 length',\
             'H2-2 length', 'Word Count', 'Text Ratio', 'Crawl Depth']]

# %%
y =  mldf['Response Time']

# %%
x
# Out:
#      Title 1 Length  Meta Description 1 Length  H1-1 length  H2-2 length  \
# 0                83                        220           21           24
# 1                49                        150           26            0
# 2                83                        182           68           21
# 3                63                        194           41           51
# 4                74                        170           38            0
# ..              ...                        ...          ...          ...
# 476              57                        172           23           21
# 477              65                        171           10            0
# 478              66                        192           23            0
# 479              67                        185           18           17
# 480              50                        190            4           22
#
#      Word Count  Text Ratio  Crawl Depth
# 0           663       8.709            0
# 1           586       3.329            1
# 2          4531       8.528            1
# 3          4373       8.205            1
# 4           413       2.957            1
# ..          ...         ...          ...
# 476        1709       4.159            2
# 477         389       5.319            2
# 478         358       5.326            2
# 479        1045       3.613            2
# 480        2683       4.696            2
#
# [481 rows x 7 columns]

# %%
y
# Out:
# 0      0.233
# 1      0.475
# 2      0.400
# 3      0.492
# 4      0.365
#        ...
# 476    0.176
# 477    0.363
# 478    0.207
# 479    0.563
# 480    0.207
# Name: Response Time, Length: 481, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg.predict(X_test)

# %%
# The coefficients
print('Coefficients: \n', reg.coef_)
# Out:
# Coefficients:
#  [ 4.42716349e-05 -8.00576919e-04 -6.80692824e-04 -2.42574606e-04
#  -3.16744421e-06  2.57267980e-03 -8.47099097e-02]

# %%
from sklearn.metrics import mean_squared_error

# %%
print('Mean squared error: %.2f'% mean_squared_error(y_test, y_pred))
# Out:
# Mean squared error: 0.01

# %%
reg.predict([[83,220,21,24,663,8.709,0]])
# Out:
# array([0.33551616])

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# <center style="font-size:40px">THANK YOU</center>

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <p style="font-size:20px; text-align:right">-- Vamshikrishna Bandari</p>
# <p style="font-size:20px; text-align:right">-- Mindadda - Machine Learning & Analytics Team</p>
